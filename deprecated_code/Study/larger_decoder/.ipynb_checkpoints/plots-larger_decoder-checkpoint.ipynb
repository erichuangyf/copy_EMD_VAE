# %%
# %ls /global/home/users/yifengh3/B_result/B_train_decoder_fixed
# Out:
# log.csv                              model_weights_end_1532_2.4e-02.hdf5
# model_weights_1046.hdf5              model_weights_end_1541_4.9e-02.hdf5
# model_weights_1086.hdf5              model_weights_end_1551_1.0e-01.hdf5
# model_weights_1178.hdf5              model_weights_end_1560_2.0e-01.hdf5
# model_weights_120.hdf5               model_weights_end_1572_4.1e-01.hdf5
# model_weights_1218.hdf5              model_weights_end_1579_8.4e-01.hdf5
# model_weights_1385.hdf5              model_weights_end_1591_1.7e+00.hdf5
# model_weights_1472.hdf5              model_weights_end_1600_3.4e+00.hdf5
# model_weights_1530.hdf5              model_weights_end_1609_7.0e+00.hdf5
# model_weights_160.hdf5               model_weights_end_225_1.0e-04.hdf5
# model_weights_200.hdf5               model_weights_end_251_1.8e-04.hdf5
# model_weights_291.hdf5               model_weights_end_299_3.2e-04.hdf5
# model_weights_383.hdf5               model_weights_end_311_5.8e-04.hdf5
# model_weights_40.hdf5                model_weights_end_343_1.0e-03.hdf5
# model_weights_477.hdf5               model_weights_end_382_1.9e-03.hdf5
# model_weights_748.hdf5               model_weights_end_398_3.4e-03.hdf5
# model_weights_788.hdf5               model_weights_end_425_6.1e-03.hdf5
# model_weights_80.hdf5                model_weights_end_437_1.1e-02.hdf5
# model_weights_828.hdf5               model_weights_end_486_2.0e-02.hdf5
# model_weights_868.hdf5               model_weights_end_516_3.5e-02.hdf5
# model_weights_908.hdf5               model_weights_end_533_6.4e-02.hdf5
# model_weights_948.hdf5               model_weights_end_549_1.1e-01.hdf5
# model_weights_988.hdf5               model_weights_end_558_2.1e-01.hdf5
# model_weights_end_1006_2.9e-03.hdf5  model_weights_end_571_3.7e-01.hdf5
# model_weights_end_1095_1.4e-03.hdf5  model_weights_end_581_6.7e-01.hdf5
# model_weights_end_1102_7.0e-04.hdf5  model_weights_end_593_1.2e+00.hdf5
# model_weights_end_1138_3.5e-04.hdf5  model_weights_end_598_2.2e+00.hdf5
# model_weights_end_1232_1.7e-04.hdf5  model_weights_end_603_3.9e+00.hdf5
# model_weights_end_1237_8.4e-05.hdf5  model_weights_end_610_7.0e+00.hdf5
# model_weights_end_1245_4.1e-05.hdf5  model_weights_end_618_3.4e+00.hdf5
# model_weights_end_1256_2.0e-05.hdf5  model_weights_end_628_1.7e+00.hdf5
# model_weights_end_1268_1.0e-05.hdf5  model_weights_end_641_8.4e-01.hdf5
# model_weights_end_1283_2.0e-05.hdf5  model_weights_end_655_4.1e-01.hdf5
# model_weights_end_1293_4.1e-05.hdf5  model_weights_end_662_2.0e-01.hdf5
# model_weights_end_1298_8.4e-05.hdf5  model_weights_end_686_1.0e-01.hdf5
# model_weights_end_1329_1.7e-04.hdf5  model_weights_end_696_4.9e-02.hdf5
# model_weights_end_1338_3.5e-04.hdf5  model_weights_end_702_2.4e-02.hdf5
# model_weights_end_1345_7.0e-04.hdf5  model_weights_end_708_1.2e-02.hdf5
# model_weights_end_1387_1.4e-03.hdf5  model_weights_end_996_5.9e-03.hdf5
# model_weights_end_1402_2.9e-03.hdf5  plots/
# model_weights_end_1432_5.9e-03.hdf5  vae_args.dat
# model_weights_end_1490_1.2e-02.hdf5

# %%
# %cd /global/home/users/yifengh3/B_result/B_train_decoder_fixed
# Out:
# /global/home/users/yifengh3/B_result/B_train_decoder_fixed

# %%
# %run ~/EMD_VAE/Study_B.py . --img_prefix ./plots/
# Out:
# Namespace(img_prefix='./plots/', model_dir='.', utils=None)
# Saving files with prefix ./plots/
# 1 Physical GPUs, 0 Logical GPUs
# Arguments count: 4
# Argument      0: /global/home/users/yifengh3/EMD_VAE/Study_B.py
# Argument      1: .
# Argument      2: --img_prefix
# Argument      3: ./plots/
# (1000000, 150)
# Memory in GB: 2.250075340270996
#
#
#  vae_arg_dict: {'encoder_conv_layers': [2048, 2048, 1028, 1024], 'dense_size': [1028, 1028, 1028, 512], 'decoder_sizes': [4096, 2048, 1028, 512, 512], 'numItermaxinner': 40, 'numIter': 10, 'reg_init': 1.0, 'reg_final': 0.01, 'stopThr': 0.001, 'num_inputs': 4, 'num_particles_in': 50}
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 50, 4)]      0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 50, 2048)     10240       inputs[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 50, 2048)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 50, 2048)     4196352     re_lu_13[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 50, 2048)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 50, 1028)     2106372     re_lu_14[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 50, 1028)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 50, 1024)     1053696     re_lu_15[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 50, 1024)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd (None, 1024)         0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1028)         1053700     tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 1028)         0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1028)         1057812     re_lu_17[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 1028)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1028)         1057812     re_lu_18[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 1028)         0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 512)          526848      re_lu_19[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 512)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 128)          65664       re_lu_20[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 128)          65664       re_lu_20[0][0]
# __________________________________________________________________________________________________
# encoder (Functional)            multiple             11194160    inputs[0][0]
# __________________________________________________________________________________________________
# tf.stack_1 (TFOpLambda)         (2, None, 128)       0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 50, 3)        11917516    encoder[0][2]
# __________________________________________________________________________________________________
# encoder_gauss_distribution (Dis multiple             0           tf.stack_1[0][0]
# ==================================================================================================
# Total params: 23,111,677
# Trainable params: 23,111,676
# Non-trainable params: 1
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function build_and_compile_annealing_vae.<locals>.recon_loss at 0x7f859c2a7670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function build_and_compile_annealing_vae.<locals>.recon_loss at 0x7f859c2a7670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 4s 4s/step - loss: 1367356.0000 - recon_loss: 3.1637 - KL loss: 5.7762 - beta: 0.0010 - val_loss: 2674886.5000 - val_recon_loss: 5.3497 - val_KL loss: 22.4508 - val_beta: 0.0010
# Preparing to load weights
# Found files: ['./model_weights_end_225_1.0e-04.hdf5', './model_weights_end_251_1.8e-04.hdf5', './model_weights_end_299_3.2e-04.hdf5', './model_weights_end_311_5.8e-04.hdf5', './model_weights_end_343_1.0e-03.hdf5', './model_weights_end_382_1.9e-03.hdf5', './model_weights_end_398_3.4e-03.hdf5', './model_weights_end_425_6.1e-03.hdf5', './model_weights_end_437_1.1e-02.hdf5', './model_weights_end_486_2.0e-02.hdf5', './model_weights_end_516_3.5e-02.hdf5', './model_weights_end_533_6.4e-02.hdf5', './model_weights_end_549_1.1e-01.hdf5', './model_weights_end_558_2.1e-01.hdf5', './model_weights_end_571_3.7e-01.hdf5', './model_weights_end_581_6.7e-01.hdf5', './model_weights_end_593_1.2e+00.hdf5', './model_weights_end_598_2.2e+00.hdf5', './model_weights_end_603_3.9e+00.hdf5', './model_weights_end_610_7.0e+00.hdf5', './model_weights_end_618_3.4e+00.hdf5', './model_weights_end_628_1.7e+00.hdf5', './model_weights_end_641_8.4e-01.hdf5', './model_weights_end_655_4.1e-01.hdf5', './model_weights_end_662_2.0e-01.hdf5', './model_weights_end_686_1.0e-01.hdf5', './model_weights_end_696_4.9e-02.hdf5', './model_weights_end_702_2.4e-02.hdf5', './model_weights_end_708_1.2e-02.hdf5', './model_weights_end_996_5.9e-03.hdf5', './model_weights_end_1006_2.9e-03.hdf5', './model_weights_end_1095_1.4e-03.hdf5', './model_weights_end_1102_7.0e-04.hdf5', './model_weights_end_1138_3.5e-04.hdf5', './model_weights_end_1232_1.7e-04.hdf5', './model_weights_end_1237_8.4e-05.hdf5', './model_weights_end_1245_4.1e-05.hdf5', './model_weights_end_1256_2.0e-05.hdf5', './model_weights_end_1268_1.0e-05.hdf5', './model_weights_end_1283_2.0e-05.hdf5', './model_weights_end_1293_4.1e-05.hdf5', './model_weights_end_1298_8.4e-05.hdf5', './model_weights_end_1329_1.7e-04.hdf5', './model_weights_end_1338_3.5e-04.hdf5', './model_weights_end_1345_7.0e-04.hdf5', './model_weights_end_1387_1.4e-03.hdf5', './model_weights_end_1402_2.9e-03.hdf5', './model_weights_end_1432_5.9e-03.hdf5', './model_weights_end_1490_1.2e-02.hdf5', './model_weights_end_1532_2.4e-02.hdf5', './model_weights_end_1541_4.9e-02.hdf5', './model_weights_end_1551_1.0e-01.hdf5', './model_weights_end_1560_2.0e-01.hdf5', './model_weights_end_1572_4.1e-01.hdf5', './model_weights_end_1579_8.4e-01.hdf5', './model_weights_end_1591_1.7e+00.hdf5', './model_weights_end_1600_3.4e+00.hdf5', './model_weights_end_1609_7.0e+00.hdf5']
# Loading file 0 of 58
# Loading file 10 of 58
# Loading file 20 of 58
# Loading file 30 of 58
# Loading file 40 of 58
# Loading file 50 of 58
# [1.0e-04 1.8e-04 3.2e-04 5.8e-04 1.0e-03 1.9e-03 3.4e-03 6.1e-03 1.1e-02
#  2.0e-02 3.5e-02 6.4e-02 1.1e-01 2.1e-01 3.7e-01 6.7e-01 1.2e+00 2.2e+00
#  3.9e+00 7.0e+00 3.4e+00 1.7e+00 8.4e-01 4.1e-01 2.0e-01 1.0e-01 4.9e-02
#  2.4e-02 1.2e-02 5.9e-03 2.9e-03 1.4e-03 7.0e-04 3.5e-04 1.7e-04 8.4e-05
#  4.1e-05 2.0e-05 1.0e-05 2.0e-05 4.1e-05 8.4e-05 1.7e-04 3.5e-04 7.0e-04
#  1.4e-03 2.9e-03 5.9e-03 1.2e-02 2.4e-02 4.9e-02 1.0e-01 2.0e-01 4.1e-01
#  8.4e-01 1.7e+00 3.4e+00 7.0e+00]
