# %%
# %cd /Users/yifenghuang/VAE/copy_EMD_VAE
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/yifenghuang/VAE/copy_EMD_VAE

# %%
from sample_and_analysis import VAE_sampler
# Out:
# INFO:tensorflow:Single-worker MultiWorkerMirroredStrategy with local_devices = ('/device:CPU:0',), communication = CommunicationImplementation.AUTO
# 2021-08-18 21:43:42.335255: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sampler = VAE_sampler("/Users/yifenghuang/VAE/data/h_signal.h5",
                     "/Users/yifenghuang/VAE/B_results/method2_beta2")
# Out:
# (50000, 150)
# Memory in GB: 0.1125037670135498
# WARNING:tensorflow:From /Users/yifenghuang/opt/anaconda3/envs/ml/lib/python3.8/site-packages/tensorflow_probability/python/distributions/distribution.py:346: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it into `scale_diag` directly instead.
# 2021-08-18 21:43:45.308273: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# inputs (InputLayer)             [(None, 50, 4)]      0
# ...

# %%
sampler.run_analysis(
    "/Users/yifenghuang/VAE/B_results/method2_beta2/end_beta_checkpoint/model_weights_end_1414_3.2e-02.hdf5",
    number_of_sampling=1,
    stop_index=1000)
# Out:
# vae input size: (1000, 50, 4)
# validation data size: (1000, 50, 3)
