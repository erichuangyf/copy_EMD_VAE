# %%
# %ls
# Out:
# compression_project/  my_Train_W.ipynb  plots.ipynb         Study-W.ipynb
# data/                 my_Train_W.py     Read_Delphes.ipynb  utils/
# __init__.py           output/           README.md

# %%
# %cd ~/EMD_VAE/output/W-test_2
# Out:
# /global/home/users/yifengh3/EMD_VAE/output/W-test_2

# %%
import json
# generate the model arg file
vae_args_file = "vae_args.dat"
vae_arg_dict = {"optimizer":keras.optimizers.Adam(lr=0.001,clipnorm=0.1),
                                    "encoder_conv_layers" : [1024,1024,1028,1024],
                                    "dense_size" :[1028,1028,1028,512],
                                    "decoder" : [2048,2048,1028,512,512],
                                    "numItermaxinner" : 40,   # EMD approximation params
                                    "numIter":10,
                                    "reg_init" : 1.,
                                    "reg_final" : 0.01,
                                    "stopThr":1e-3,
                                    "num_inputs":5,           # Size of x (e.g. pT, eta, sin, cos, log E)
                                    "num_particles_in":50}


with open(vae_args_file,'w') as file:
  file.write(json.dumps(vae_arg_dict))

# %%
# %ls
# Out:
# log.csv                 model_weights_60.hdf5
# model_weights_103.hdf5  model_weights_610.hdf5
# model_weights_10.hdf5   model_weights_620.hdf5
# model_weights_113.hdf5  model_weights_635.hdf5
# model_weights_129.hdf5  model_weights_645.hdf5
# model_weights_139.hdf5  model_weights_655.hdf5
# model_weights_149.hdf5  model_weights_665.hdf5
# model_weights_159.hdf5  model_weights_676.hdf5
# model_weights_169.hdf5  model_weights_686.hdf5
# model_weights_179.hdf5  model_weights_696.hdf5
# model_weights_189.hdf5  model_weights_706.hdf5
# model_weights_201.hdf5  model_weights_70.hdf5
# model_weights_20.hdf5   model_weights_716.hdf5
# model_weights_211.hdf5  model_weights_726.hdf5
# model_weights_221.hdf5  model_weights_741.hdf5
# model_weights_231.hdf5  model_weights_750.hdf5
# model_weights_241.hdf5  model_weights_759.hdf5
# model_weights_251.hdf5  model_weights_768.hdf5
# model_weights_261.hdf5  model_weights_777.hdf5
# model_weights_271.hdf5  model_weights_786.hdf5
# ...

# %%
# %run ~/VAE_master/Study_W.py .
# Out:
# Namespace(img_prefix=None, model_dir='.', utils=None)
# Saving files with prefix ./
# 1 Physical GPUs, 0 Logical GPUs
# Arguments count: 2
# Argument      0: /global/home/users/yifengh3/VAE_master/Study_W.py
# Argument      1: .
# (100000, 200)
# Memory in GB: 0.2995133399963379
# /global/home/users/yifengh3/VAE_master/Study_W.py:118: RuntimeWarning: invalid value encountered in true_divide
#   y = 0.5*np.nan_to_num(np.log((E+pz)/(E-pz)))
# /global/home/users/yifengh3/VAE_master/Study_W.py:139: RuntimeWarning: invalid value encountered in true_divide
#   eta = np.nan_to_num(np.arcsinh(np.sinh(y)*np.sqrt(1+np.square(m/pt))))
#  vae_arg_dict: {'encoder_conv_layers': [1024, 1024, 1028, 1024], 'dense_size': [1028, 1028, 1028, 512], 'decoder_sizes': [2048, 2048, 1028, 512, 512], 'numIter': 10, 'reg_init': 1.0, 'reg_final': 0.01, 'stopThr': 0.001, 'num_inputs': 5, 'num_particles_in': 50, 'latent_dim': 128, 'verbose': 1, 'dropout': 0.1}
# ...
