# %%
# %cd /global/home/users/yifengh3/VAE/B_results/annealing_1
# Out:
# /global/home/users/yifengh3/VAE/B_results/annealing_1

# %%
# %ls
# Out:
# beta_schedule.png  end_beta_checkpoint/  plots/
# checkpoint/        log.csv               vae_args.dat

# %%
# %mkdir plots
# Out:
# mkdir: cannot create directory ‘plots’: File exists

# %%
# %run /global/home/users/yifengh3/VAE/EMD_VAE/Study_B.py /global/home/users/yifengh3/VAE/B_results/method2_beta2 --img_prefix ./plots/
# Out:
# Namespace(img_prefix='./plots/', model_dir='/global/home/users/yifengh3/VAE/B_results/method2_beta2', utils=None)
# Saving files with prefix ./plots/
# 1 Physical GPUs, 1 Logical GPUs
# Arguments count: 4
# Argument      0: /global/home/users/yifengh3/VAE/EMD_VAE/Study_B.py
# Argument      1: /global/home/users/yifengh3/VAE/B_results/method2_beta2
# Argument      2: --img_prefix
# Argument      3: ./plots/
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/device:GPU:0',)
# INFO:tensorflow:Single-worker MultiWorkerMirroredStrategy with local_devices = ('/device:GPU:0',), communication = CommunicationImplementation.AUTO
# (1000000, 150)
# Memory in GB: 2.250075340270996
#
#
# ...

# %%
# release the memory :)
from numba import cuda 
device = cuda.get_current_device()
device.reset()
