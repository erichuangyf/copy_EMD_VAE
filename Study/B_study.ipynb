# %%
# %cd /global/home/users/yifengh3/VAE/B_results/method2_beta2
# Out:
# /global/home/users/yifengh3/VAE/B_results/method2_beta2

# %%
# %ls
# Out:
# checkpoint/  end_beta_checkpoint/  log.csv  plots/  vae_args.dat

# %%
# %mkdir plots

# %%
# %run /global/home/users/yifengh3/VAE/EMD_VAE/Study_B.py . --img_prefix ./plots/
# Out:
# Namespace(img_prefix='./plots/', model_dir='.', utils=None)
# Saving files with prefix ./plots/
# 1 Physical GPUs, 0 Logical GPUs
# Arguments count: 4
# Argument      0: /global/home/users/yifengh3/VAE/EMD_VAE/Study_B.py
# Argument      1: .
# Argument      2: --img_prefix
# Argument      3: ./plots/
# (1000000, 150)
# Memory in GB: 2.250075340270996
#
#
#  vae_arg_dict: {'encoder_conv_layers': [1024, 1024, 1024, 1024], 'dense_size': [1024, 1024, 1024, 1024], 'decoder_sizes': [1024, 1024, 1024, 1024, 1024], 'numItermaxinner': 20, 'numIter': 10, 'reg_init': 1.0, 'reg_final': 0.01, 'stopThr': 0.001, 'num_inputs': 4, 'num_particles_in': 50}
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 50, 4)]      0
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 50, 1024)     5120        inputs[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 50, 1024)     0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 50, 1024)     1049600     re_lu_39[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 50, 1024)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 50, 1024)     1049600     re_lu_40[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 50, 1024)     0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 50, 1024)     1049600     re_lu_41[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 50, 1024)     0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_3 (TFOpLambd (None, 1024)         0           re_lu_42[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1024)         1049600     tf.math.reduce_sum_3[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 1024)         0           dense_30[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1024)         1049600     re_lu_43[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 1024)         0           dense_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1024)         1049600     re_lu_44[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 1024)         0           dense_32[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 1024)         1049600     re_lu_45[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 1024)         0           dense_33[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 128)          131200      re_lu_46[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 128)          131200      re_lu_46[0][0]
# __________________________________________________________________________________________________
# encoder (Functional)            multiple             7614720     inputs[0][0]
# __________________________________________________________________________________________________
# tf.stack_3 (TFOpLambda)         (2, None, 128)       0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 50, 3)        4535496     encoder[0][2]
# __________________________________________________________________________________________________
# encoder_gauss_distribution (Dis multiple             0           tf.stack_3[0][0]
# ==================================================================================================
# Total params: 12,150,217
# Trainable params: 12,150,216
# Non-trainable params: 1
# __________________________________________________________________________________________________
# WARNING:tensorflow:AutoGraph could not transform <function build_and_compile_annealing_vae.<locals>.recon_loss at 0x7f61080b8a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function build_and_compile_annealing_vae.<locals>.recon_loss at 0x7f61080b8a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 3s 3s/step - loss: 2613923.0000 - recon_loss: 5.2278 - KL loss: 20.4446 - beta: 0.0010 - val_loss: 2568251.5000 - val_recon_loss: 5.1364 - val_KL loss: 27.2190 - val_beta: 0.0010
# Preparing to load weights
# Found files: ['./end_beta_checkpoint/model_weights_end_223_1.0e-05.hdf5', './end_beta_checkpoint/model_weights_end_321_1.8e-05.hdf5', './end_beta_checkpoint/model_weights_end_437_3.2e-05.hdf5', './end_beta_checkpoint/model_weights_end_553_5.6e-05.hdf5', './end_beta_checkpoint/model_weights_end_745_1.0e-04.hdf5', './end_beta_checkpoint/model_weights_end_767_1.8e-04.hdf5', './end_beta_checkpoint/model_weights_end_867_3.2e-04.hdf5', './end_beta_checkpoint/model_weights_end_941_5.6e-04.hdf5']
# Loading file 0 of 8
# [1.0e-05 1.8e-05 3.2e-05 5.6e-05 1.0e-04 1.8e-04 3.2e-04 5.6e-04]
# [10447009000.0, 4508059000.0, 1454072400.0, 441801760.0, 127721290.0, 36654120.0, 10978068.0, 3385281.2]
# [2.0894015, 2.9212222, 2.9779398, 2.7709794, 2.554422, 2.3751767, 2.2482784, 2.1231685]
# [615.1102, 326.96625, 276.9171, 221.99762, 185.92644, 165.06741, 145.64983, 127.756966]
# [1 8]
# [array([1.0e-05, 1.8e-05, 3.2e-05, 5.6e-05, 1.0e-04, 1.8e-04, 3.2e-04,
#        5.6e-04])]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/VAE/EMD_VAE/Study_B.py in <module>
#     521     ax = fig.axes[0]
#     522     sec_ax = ax.secondary_xaxis('top',functions=(beta_to_betap,betap_to_beta))
# --> 523     plt.title(args.img_title)
#     524     plt.xlabel(r'$\beta$')
#     525     plt.ylabel('KL')
#
# AttributeError: 'Namespace' object has no attribute 'img_title'
