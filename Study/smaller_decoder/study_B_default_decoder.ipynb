# %% [markdown]
# # B jet study

# %%
# %cd /global/home/users/yifengh3/EMD_VAE
# Out:
# /global/home/users/yifengh3/EMD_VAE

# %%
import tensorflow as tf
tf.config.experimental.set_visible_devices([], 'GPU')
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

import tensorflow.keras as keras
import tensorflow.keras.backend as K

import os
import os.path as osp
import sys

import numpy as np

import matplotlib
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

from utils.tf_sinkhorn import ground_distance_tf_nograd, sinkhorn_knopp_tf_scaling_stabilized_class
import utils.VAE_model_tools
from utils.VAE_model_tools import build_and_compile_annealing_vae, betaVAEModel, reset_metrics

import pandas
import matplotlib.pyplot as plt

import h5py
import pickle
from scipy.stats import gaussian_kde
# Out:
# 1 Physical GPUs, 0 Logical GPUs
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/device:CPU:0',)
# INFO:tensorflow:Single-worker MultiWorkerMirroredStrategy with local_devices = ('/device:CPU:0',), communication = CommunicationImplementation.AUTO

# %%
def create_dir(dir_path):
    ''' Creates a directory (or nested directories) if they don't exist.
    '''
    if not osp.exists(dir_path):
        os.makedirs(dir_path)

    return dir_path

output_dir = './data/'
    
def kl_loss(z_mean, z_log_var):
    return -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
    
    
from pyjet import cluster

def get_clustered_pt_eta_phi(pts, locations,R=0.1):
    weights = pts
    outjet = locations
    myjet = np.zeros((weights.shape[-1]),dtype=([('pT', 'f8'), ('eta', 'f8'), ('phi', 'f8'), ('mass', 'f8')]))
    myjet['pT'] = weights
    myjet['eta'] = outjet[:,0]
    myjet['phi'] = outjet[:,1]
    sequence = cluster(myjet,R=R,p=0)
    jets = sequence.inclusive_jets()
    phis = np.array([np.mod(np.pi+jet.phi,2*np.pi)-np.pi for jet in jets])
    etas = np.array([jet.eta for jet in jets])
    pts = np.array([jet.pt for jet in jets])
    
    return pts, etas, phis


def plot_jets(outs_array, numplot = 3, R=0.02,size=50, save_dir = None):
    etalim=5
    #bins=np.linspace(-lim, lim, 126)

    for i in range(numplot):   

        fig, ax = plt.subplots(1, 3,figsize=[15,5],sharey=True)



        outjet = valid_y[i,:,1:]
        weights = valid_y[i,:,0]
        pts, etas, phis = get_clustered_pt_eta_phi(weights, outjet,R=R)
        ax[0].scatter(phis, etas, s = pts*size, alpha = 0.7,linewidths=0)
        ax[0].set_title('Jet'+str(i),y=0.9)

        #ax[0].hist2d(feed_pc[i][:,0],feed_pc[i][:,1],range=[[-lim,lim],[-lim,lim]],bins=bins, norm=LogNorm(0.5, 1000))
        for j in range(2):
            outjet = outs_array[j][0][i,:,1:]
            weights = outs_array[j][0][i,:,0]
            pts, etas, phis = get_clustered_pt_eta_phi(weights, outjet,R=R)
            ax[j+1].scatter(phis, etas, s = pts*size, alpha = 0.7,linewidths=0)
            ax[j+1].set_title('Sample'+ str(j),y=0.9)
            
        for j in range(3):
            
            
            ax[j].set_ylim([-5,5])
            ax[j].set_xlim([-np.pi,np.pi])

        plt.subplots_adjust(wspace=0, hspace=0)
        if save_dir:
            outfile = os.path.join(save_dir,"jets_plot_{}.png".format(i))
            plt.savefig(outfile)
        plt.show()
        
def plot_KL_logvar(outs_array,xlim=None,ylim=None):
    
    _, z_mean, z_log_var, z = outs_array[0]

    KL=kl_loss(z_mean, z_log_var)
    sort_kl = np.flip(np.argsort(np.mean(KL,axis=0)))

    rms_mean = np.sqrt(np.mean(np.square(z_mean),axis=0))

    plt.scatter(np.mean(KL,axis=0),rms_mean,s=5.)

    if ylim:
        plt.ylim(ylim)
    if xlim:
        plt.xlim(xlim)
        
    plt.xlabel('KL divergence')
    plt.ylabel(r'$\sqrt{\left\langle \mu^2 \right\rangle}$')
    plt.show()
    
    return sort_kl

def get_plot(file, save_dir = None):
    vae.load_weights(file)
    beta = get_beta(file)
    outs_array = [vae.predict(valid_x[:1000]) for j in range(3)]
    output_dir = None
    
    if save_dir:
        output_dir = os.path.join(save_dir,"epoch{}_beta{}".format(get_epoch(file),get_beta(file)))
        create_dir(output_dir)
    
    vae.beta.assign(beta)
    result = vae.test_step([valid_x[:2000].astype(np.float32),valid_y[:2000].astype(np.float32)])
    
    print("epoch = {}".format(get_epoch(file)))
    print("Beta = {}".format(beta))
    print("Loss:", "{:.02e}".format(result['loss'].numpy()))
    print("Recon loss:", "{:.02e}".format(result['recon_loss'].numpy()))
    print("KL loss:", result['KL loss'].numpy())

    print()

    print("KL divergences plot. x axis is ~ log(resolution) for resolution << 1")
    sort_kl = plot_KL_logvar(outs_array,[-0.1,None],[-0.1,None])

    print("Jet sample plots. Left = original jet. Middle and right: two vae samples")
    plot_jets(outs_array,R=0.05,size=1000,save_dir=output_dir)

    print("Latent space distributions in most important latent space directions")
    _, z_mean, z_log_var, z = outs_array[0]

    plt.scatter(z_mean[:,sort_kl[0]],z_mean[:,sort_kl[1]],s=1.)
    plt.xlabel(r'$\sqrt{\left\langle \mu_0^2 \right\rangle}$')
    plt.ylabel(r'$\sqrt{\left\langle \mu_1^2 \right\rangle}$')
    plt.show()
    plt.scatter(z_mean[:,sort_kl[2]],z_mean[:,sort_kl[3]],s=1.)
    plt.xlabel(r'$\sqrt{\left\langle \mu_2^2 \right\rangle}$')
    plt.ylabel(r'$\sqrt{\left\langle \mu_3^2 \right\rangle}$')
    plt.show()

    plt.scatter(z_mean[:,sort_kl[0]],z_log_var[:,sort_kl[0]],s=1.)
    plt.xlabel(r'$\sqrt{\left\langle \mu_0^2 \right\rangle}$')
    plt.ylabel(r'$\left\langle \log \sigma_0 \right\rangle$')
    plt.show()
    plt.scatter(z_mean[:,sort_kl[1]],z_log_var[:,sort_kl[1]],s=1.)
    plt.xlabel(r'$\sqrt{\left\langle \mu_1^2 \right\rangle}$')
    plt.ylabel(r'$\left\langle \log \sigma_1 \right\rangle$')
    plt.show()

#     print("Investigation of first two latent directions. Salmon is unpopulated regions of the latent space (see scatter plots above).Note that opposite points on the disk are very similar, which reflects the topology of 2-body decays. A two body decay is specified by two coordinates, phi and theta (in the rest frame) or z (in the boosted frame) for one of the particles. This is the sphere S^2 with the phi coordinate determining longitude and z/theta determining latitude (the equator is balanced jets, the poles is maximially unbalanced). If the particles are considered identical, then antipodes are identified (which is the geometry of RP^2). The sphere is a double cover of the decay kinematics (if you know z and phi for particle 1, then you know it also for particle 2). The shape you see below is a projection of a hemisphere of that. The topology of the latent space is R^n, which cannot faithfully reproduce RP^2, but it is trying its best. Jets that are close to eachother in real space correspond to latent points that are close in the latent space, except at the rim of the disk where a small change in real space can take you straight to the opposite edge of the disk. As the resolution of the VAE gets finer and finer, this affects a smaller and smaller annulus of jets around the rim of the disk.")

    narray = 11
    lim = 3.0
    codes = np.zeros((narray**2,128))

    dirs = [0,1]

    for i in range(narray):
        for j in range(narray):
            codes[narray*i+j,sort_kl[dirs[0]]] = (i-(narray-1)/2)*lim/((narray-1)/2)
            codes[narray*i+j,sort_kl[dirs[1]]] = (j-(narray-1)/2)*lim/((narray-1)/2)

    decoded = decoder.predict(codes)

    fig, ax = plt.subplots(narray, narray,figsize=[15,15],sharex=True,sharey=True)

    for i in range(narray):
        for j in range(narray):
            outjet = decoded[narray*i+j,:,1:]
            weights = decoded[narray*i+j,:,0]
            pts, etas, phis = get_clustered_pt_eta_phi(weights, outjet,R=0.05)
            x=codes[narray*i+j,sort_kl[dirs[0]]]
            y=codes[narray*i+j,sort_kl[dirs[1]]]
            if np.square(x) + np.square(y) > np.square(2.7):
                ax[i,j].set_facecolor('xkcd:salmon')
            ax[i,j].scatter(phis, etas, s = pts*1000, alpha = 0.7,linewidths=0)
            ax[i,j].set_xlim(-0.5,0.5)
            ax[i,j].set_ylim(-0.5,0.5)
            ax[i,j].set_title('['+'{:.1f}'.format(x)+','+'{:.1f}'.format(y)+']',
                             y=0.8)
    #         ax[j,i].set_aspect('equal')
    ax[int((narray-1)/2),int((narray-1)/2)].set_facecolor([0.9,0.9,0.9])
    plt.subplots_adjust(wspace=0, hspace=0)
    if save_dir:
        outfile = os.path.join(output_dir,"salmon_plot.png".format(i))
        plt.savefig(outfile)
    plt.show()


def load_weights(file, save_dir = None,xlim=None,ylim=None):
    vae.load_weights(file)
    
    if save_dir:
        create_dir(save_dir)
    
    outs_array = [vae.predict(valid_x[:1000]) for j in range(3)]
    _, z_mean, z_log_var, z = outs_array[0]

    KL=kl_loss(z_mean, z_log_var)
    sort_kl = np.flip(np.argsort(np.mean(KL,axis=0)))

    rms_mean = np.sqrt(np.mean(np.square(z_mean),axis=0))

    plt.scatter(np.mean(KL,axis=0),rms_mean,s=5.)

    if ylim:
        plt.ylim(ylim)
    if xlim:
        plt.xlim(xlim)
        
    plt.xlabel('KL divergence')
    plt.ylabel(r'$\sqrt{\left\langle \mu^2 \right\rangle}$')
    plt.title("epoch = {}, beta = {}".format(get_epoch(file),get_beta(file)))
    if save_dir:
        outfile = os.path.join(save_dir,"KL_plot_{}_{}.png".format(get_epoch(file),get_beta(file)))
        plt.savefig(outfile)
    plt.show()
    
import glob
import re

def get_epoch(file):
    epoch_string=re.compile('_\d*_')
    epoch = int(epoch_string.search(file).group()[1:-1])
    return epoch

def get_beta(file):
    beta_string=re.compile('\d\.[\w\+-]*')
    beta = float(beta_string.search(file).group())
    return beta

def generate_sample_plots(weight_file, validation_index = None, size = 1000,R = 0.02, base_save_dir = None):
    vae.load_weights(weight_file)
    beta = get_beta(weight_file)
    epoch = get_epoch(weight_file)
    outs_array = [vae.predict(valid_x[:1000]) for j in range(3)]
    outs_array = [vae.predict(valid_x[:1000]) for j in range(3)]
    save_dir= None
    
    if base_save_dir:
        save_dir = os.path.join(base_save_dir,"jet_sample_{}_{}".format(epoch,beta))
        create_dir(save_dir)
        print("saving to {}".format(save_dir))
    
    if type(validation_index) is type(None):
        validation_index = np.array([7,10,18,28])
        validation_index -= 1
    numplot = len(validation_index)
    for i in range(numplot):   
        
        fig, ax = plt.subplots(1, 3,figsize=[15,5],sharey=True)
        outjet = valid_y[validation_index[i],:,1:]
        weights = valid_y[validation_index[i],:,0]
        pts, etas, phis = get_clustered_pt_eta_phi(weights, outjet,R=R)
        ax[0].scatter(phis, etas, s = pts*size, alpha = 0.7,linewidths=0)
        ax[0].set_title('Jet'+str(validation_index[i]),y=0.9)

        #ax[0].hist2d(feed_pc[i][:,0],feed_pc[i][:,1],range=[[-lim,lim],[-lim,lim]],bins=bins, norm=LogNorm(0.5, 1000))
        for j in range(2):
            outjet = outs_array[j][0][validation_index[i],:,1:]
            weights = outs_array[j][0][validation_index[i],:,0]
            pts, etas, phis = get_clustered_pt_eta_phi(weights, outjet,R=R)
            ax[j+1].scatter(phis, etas, s = pts*size, alpha = 0.7,linewidths=0)
            ax[j+1].set_title('Sample'+ str(j),y=0.9)

        for j in range(3):


            ax[j].set_ylim([-5,5])
            ax[j].set_xlim([-np.pi,np.pi])

        plt.subplots_adjust(wspace=0, hspace=0)
        if save_dir:
            outfile = os.path.join(save_dir,"jet_plot_{}.png".format(i))
            plt.savefig(outfile)
        plt.show()

# %% [markdown]
# # Set up model

# %%
# path to file
fn =  '/global/home/users/yifengh3/data/B_background.h5'

df = pandas.read_hdf(fn,stop=1000000)
print(df.shape)
print("Memory in GB:",sum(df.memory_usage(deep=True)) / (1024**3)+sum(df.memory_usage(deep=True)) / (1024**3))

# Data file contains, for each event, 50 particles (with zero padding), each particle with pT, eta, phi
data = df.values.reshape((-1,50,3))

# Normalize pTs so that HT = 1
HT = np.sum(data[:,:,0],axis=-1)
data[:,:,0] = data[:,:,0]/HT[:,None]

# Inputs x to NN will be: pT, eta, cos(phi), sin(phi), log E
# Separated phi into cos and sin for continuity around full detector, so make things easier for NN.
# Also adding the log E is mainly because it seems like it should make things easier for NN, since there is an exponential spread in particle energies.
# Feel free to change these choices as desired. E.g. px, py might be equally as good as pt, sin, cos.
sig_input = np.zeros((len(data),50,4))
sig_input[:,:,:2] = data[:,:,:2]
sig_input[:,:,2] = np.cos(data[:,:,2])
sig_input[:,:,3] = np.sin(data[:,:,2])
# no input from energy for B jets
# sig_input[:,:,4] = np.log(data[:,:,3]+1e-8)


data_x = sig_input
# Event 'labels' y are [pT, eta, phi], which is used to calculate EMD to output which is also pT, eta, phi.
data_y = data


train_x = data_x[:800000]
train_y = data_y[:800000]
valid_x = data_x[800000:]
valid_y = data_y[800000:]
# Out:
# (1000000, 150)
# Memory in GB: 2.250075340270996

# %%
# %cd /global/home/users/yifengh3/B_result/B_train_1
# Out:
# /global/home/users/yifengh3/B_result/B_train_1

# %%
import json
vae_args_file = "./vae_args.dat"
with open(vae_args_file,'r') as f:
  vae_arg_dict = json.loads(f.read())

print("\n\n vae_arg_dict:", vae_arg_dict)

vae, encoder, decoder = build_and_compile_annealing_vae(**vae_arg_dict)

batch_size=150
save_period=2

vae.beta.assign(0.001)

K.set_value(vae.optimizer.lr,1e-4)
# Out:
#  vae_arg_dict: {'encoder_conv_layers': [1024, 1024, 1028, 1024], 'dense_size': [1028, 1028, 1028, 512], 'decoder': [2048, 2048, 1028, 512, 512], 'numItermaxinner': 40, 'numIter': 10, 'reg_init': 1.0, 'reg_final': 0.01, 'stopThr': 0.001, 'num_inputs': 4, 'num_particles_in': 50}
# WARNING:tensorflow:From /global/home/users/yifengh3/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/ops/linalg/linear_operator_diag.py:167: calling LinearOperator.__init__ (from tensorflow.python.ops.linalg.linear_operator) with graph_parents is deprecated and will be removed in a future version.
# Instructions for updating:
# Do not pass `graph_parents`.  They will  no longer be used.
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 50, 4)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 50, 1024)     5120        inputs[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 50, 1024)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 50, 1024)     1049600     re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 50, 1024)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 50, 1028)     1053700     re_lu_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 50, 1028)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 50, 1024)     1053696     re_lu_2[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 50, 1024)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None, 1024)         0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1028)         1053700     tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 1028)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1028)         1057812     re_lu_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 1028)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1028)         1057812     re_lu_5[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 1028)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          526848      re_lu_6[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 512)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 128)          65664       re_lu_7[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 128)          65664       re_lu_7[0][0]
# __________________________________________________________________________________________________
# encoder (Functional)            multiple             6989616     inputs[0][0]
# __________________________________________________________________________________________________
# tf.stack (TFOpLambda)           (2, None, 128)       0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 50, 3)        380360      encoder[0][2]
# __________________________________________________________________________________________________
# encoder_gauss_distribution (Dis multiple             0           tf.stack[0][0]
# ==================================================================================================
# Total params: 7,369,977
# Trainable params: 7,369,976
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %%
# %cd /global/home/users/yifengh3/B_result/B_train_1
# Out:
# /global/home/users/yifengh3/B_result/B_train_1

# %%
print("Preparing to load weights")
train_output_dir = "/global/home/users/yifengh3/B_result/B_train_1"

files = glob.glob(os.path.join(train_output_dir + '/model_weights_end*.hdf5'))
files.sort(key=os.path.getmtime)
epochs = np.array([get_epoch(file) for file in files])
betas = np.array([get_beta(file) for file in files])
# Out:
# Preparing to load weights

# %%
for file in files:
    load_weights(file,"/global/home/users/yifengh3/B_result/weight_summary_after_annealing")

# %%
interesting_val_index = [9,11,17,27,31,36,68,73,74,76,88,]

# %%
# %ls
# Out:
# log.csv                              model_weights_end_1936_8.8e-01.hdf5
# model_weights_1006.hdf5              model_weights_end_1944_6.3e-01.hdf5
# model_weights_100.hdf5               model_weights_end_1967_4.4e-01.hdf5
# model_weights_1026.hdf5              model_weights_end_1979_3.1e-01.hdf5
# model_weights_1046.hdf5              model_weights_end_1990_2.2e-01.hdf5
# model_weights_1066.hdf5              model_weights_end_2008_1.6e-01.hdf5
# model_weights_1097.hdf5              model_weights_end_2013_1.1e-01.hdf5
# model_weights_1117.hdf5              model_weights_end_2030_7.9e-02.hdf5
# model_weights_1137.hdf5              model_weights_end_2040_5.6e-02.hdf5
# model_weights_1157.hdf5              model_weights_end_2113_4.0e-02.hdf5
# model_weights_1191.hdf5              model_weights_end_2141_2.8e-02.hdf5
# model_weights_120.hdf5               model_weights_end_2229_2.0e-02.hdf5
# model_weights_1211.hdf5              model_weights_end_2247_1.4e-02.hdf5
# model_weights_1231.hdf5              model_weights_end_2358_1.0e-02.hdf5
# model_weights_1251.hdf5              model_weights_end_2369_1.0e-02.hdf5
# model_weights_1285.hdf5              model_weights_end_2384_1.2e-02.hdf5
# model_weights_1305.hdf5              model_weights_end_2401_1.4e-02.hdf5
# model_weights_1325.hdf5              model_weights_end_2416_1.7e-02.hdf5
# model_weights_1345.hdf5              model_weights_end_2430_2.0e-02.hdf5
# model_weights_1382.hdf5              model_weights_end_2437_2.4e-02.hdf5
# model_weights_1409.hdf5              model_weights_end_2449_2.9e-02.hdf5
# model_weights_140.hdf5               model_weights_end_2459_3.5e-02.hdf5
# model_weights_1443.hdf5              model_weights_end_2477_4.2e-02.hdf5
# model_weights_1463.hdf5              model_weights_end_2482_5.0e-02.hdf5
# model_weights_1483.hdf5              model_weights_end_2487_6.0e-02.hdf5
# model_weights_1503.hdf5              model_weights_end_2497_7.2e-02.hdf5
# model_weights_1523.hdf5              model_weights_end_2502_8.6e-02.hdf5
# model_weights_1549.hdf5              model_weights_end_2518_1.0e-01.hdf5
# model_weights_1590.hdf5              model_weights_end_2533_1.2e-01.hdf5
# model_weights_160.hdf5               model_weights_end_2543_1.5e-01.hdf5
# model_weights_1658.hdf5              model_weights_end_2548_1.8e-01.hdf5
# model_weights_1719.hdf5              model_weights_end_2553_2.1e-01.hdf5
# model_weights_1739.hdf5              model_weights_end_2560_2.5e-01.hdf5
# model_weights_1773.hdf5              model_weights_end_2566_3.0e-01.hdf5
# model_weights_180.hdf5               model_weights_end_2571_1.5e-01.hdf5
# model_weights_1823.hdf5              model_weights_end_2582_1.1e-01.hdf5
# model_weights_200.hdf5               model_weights_end_2595_8.2e-02.hdf5
# model_weights_2080.hdf5              model_weights_end_2616_6.1e-02.hdf5
# model_weights_20.hdf5                model_weights_end_2623_4.5e-02.hdf5
# model_weights_2181.hdf5              model_weights_end_2632_3.3e-02.hdf5
# model_weights_220.hdf5               model_weights_end_2690_2.5e-02.hdf5
# model_weights_2221.hdf5              model_weights_end_2742_1.8e-02.hdf5
# model_weights_2287.hdf5              model_weights_end_2790_1.4e-02.hdf5
# model_weights_2327.hdf5              model_weights_end_2829_1.0e-02.hdf5
# model_weights_240.hdf5               model_weights_end_2874_7.5e-03.hdf5
# model_weights_260.hdf5               model_weights_end_2897_5.5e-03.hdf5
# model_weights_2672.hdf5              model_weights_end_2973_4.1e-03.hdf5
# model_weights_2730.hdf5              model_weights_end_3019_3.0e-03.hdf5
# model_weights_2782.hdf5              model_weights_end_3043_2.2e-03.hdf5
# model_weights_280.hdf5               model_weights_end_3067_1.7e-03.hdf5
# model_weights_2830.hdf5              model_weights_end_3081_1.2e-03.hdf5
# model_weights_2869.hdf5              model_weights_end_3088_9.1e-04.hdf5
# model_weights_2937.hdf5              model_weights_end_3110_6.8e-04.hdf5
# model_weights_300.hdf5               model_weights_end_3127_5.0e-04.hdf5
# model_weights_3013.hdf5              model_weights_end_3178_5.0e-04.hdf5
# model_weights_3167.hdf5              model_weights_end_3207_6.6e-04.hdf5
# model_weights_320.hdf5               model_weights_end_3286_8.7e-04.hdf5
# model_weights_3247.hdf5              model_weights_end_3307_1.2e-03.hdf5
# model_weights_3287.hdf5              model_weights_end_331_1.0e-04.hdf5
# model_weights_371.hdf5               model_weights_end_3325_1.5e-03.hdf5
# model_weights_3720.hdf5              model_weights_end_3347_2.0e-03.hdf5
# model_weights_3782.hdf5              model_weights_end_3353_2.7e-03.hdf5
# model_weights_3897.hdf5              model_weights_end_3373_3.5e-03.hdf5
# model_weights_3968.hdf5              model_weights_end_3378_4.7e-03.hdf5
# model_weights_408.hdf5               model_weights_end_3410_6.2e-03.hdf5
# model_weights_40.hdf5                model_weights_end_342_1.8e-04.hdf5
# model_weights_447.hdf5               model_weights_end_3434_8.1e-03.hdf5
# model_weights_473.hdf5               model_weights_end_3463_1.1e-02.hdf5
# model_weights_495.hdf5               model_weights_end_3485_1.4e-02.hdf5
# model_weights_515.hdf5               model_weights_end_351_3.2e-04.hdf5
# model_weights_535.hdf5               model_weights_end_3515_1.9e-02.hdf5
# model_weights_555.hdf5               model_weights_end_3532_2.5e-02.hdf5
# model_weights_574.hdf5               model_weights_end_3539_3.3e-02.hdf5
# model_weights_595.hdf5               model_weights_end_3551_4.3e-02.hdf5
# model_weights_60.hdf5                model_weights_end_3560_5.7e-02.hdf5
# model_weights_734.hdf5               model_weights_end_3583_7.6e-02.hdf5
# model_weights_761.hdf5               model_weights_end_3598_1.0e-01.hdf5
# model_weights_781.hdf5               model_weights_end_3610_1.0e-01.hdf5
# model_weights_801.hdf5               model_weights_end_3617_7.3e-02.hdf5
# model_weights_80.hdf5                model_weights_end_3633_5.3e-02.hdf5
# model_weights_821.hdf5               model_weights_end_3643_3.9e-02.hdf5
# model_weights_841.hdf5               model_weights_end_3680_2.8e-02.hdf5
# model_weights_862.hdf5               model_weights_end_3725_2.1e-02.hdf5
# model_weights_882.hdf5               model_weights_end_372_5.8e-04.hdf5
# model_weights_902.hdf5               model_weights_end_3742_1.5e-02.hdf5
# model_weights_922.hdf5               model_weights_end_3799_1.1e-02.hdf5
# model_weights_942.hdf5               model_weights_end_3816_8.0e-03.hdf5
# model_weights_962.hdf5               model_weights_end_3842_5.9e-03.hdf5
# model_weights_982.hdf5               model_weights_end_3857_4.3e-03.hdf5
# model_weights_end_1077_5.9e-03.hdf5  model_weights_end_388_1.0e-03.hdf5
# model_weights_end_1171_2.9e-03.hdf5  model_weights_end_3916_3.1e-03.hdf5
# model_weights_end_1265_1.4e-03.hdf5  model_weights_end_3928_2.3e-03.hdf5
# model_weights_end_1348_7.0e-04.hdf5  model_weights_end_3990_1.7e-03.hdf5
# model_weights_end_1362_3.5e-04.hdf5  model_weights_end_4011_1.2e-03.hdf5
# model_weights_end_1389_1.7e-04.hdf5  model_weights_end_4036_8.8e-04.hdf5
# model_weights_end_1423_8.4e-05.hdf5  model_weights_end_4047_6.4e-04.hdf5
# model_weights_end_1529_4.1e-05.hdf5  model_weights_end_4082_4.7e-04.hdf5
# model_weights_end_1555_2.0e-05.hdf5  model_weights_end_4102_3.4e-04.hdf5
# model_weights_end_1570_1.0e-05.hdf5  model_weights_end_4108_2.5e-04.hdf5
# model_weights_end_1599_2.0e-05.hdf5  model_weights_end_417_1.9e-03.hdf5
# model_weights_end_1612_4.1e-05.hdf5  model_weights_end_427_3.4e-03.hdf5
# model_weights_end_1619_8.4e-05.hdf5  model_weights_end_453_6.1e-03.hdf5
# model_weights_end_1633_1.7e-04.hdf5  model_weights_end_475_1.1e-02.hdf5
# model_weights_end_1638_3.5e-04.hdf5  model_weights_end_554_2.0e-02.hdf5
# model_weights_end_1668_7.0e-04.hdf5  model_weights_end_575_3.5e-02.hdf5
# model_weights_end_1676_1.4e-03.hdf5  model_weights_end_597_6.4e-02.hdf5
# model_weights_end_1690_2.9e-03.hdf5  model_weights_end_613_1.1e-01.hdf5
# model_weights_end_1699_5.9e-03.hdf5  model_weights_end_620_2.1e-01.hdf5
# model_weights_end_1753_1.2e-02.hdf5  model_weights_end_631_3.7e-01.hdf5
# model_weights_end_1776_2.4e-02.hdf5  model_weights_end_643_6.7e-01.hdf5
# model_weights_end_1788_4.9e-02.hdf5  model_weights_end_651_1.2e+00.hdf5
# model_weights_end_1803_1.0e-01.hdf5  model_weights_end_657_2.2e+00.hdf5
# model_weights_end_1823_2.0e-01.hdf5  model_weights_end_662_3.9e+00.hdf5
# model_weights_end_1828_4.1e-01.hdf5  model_weights_end_670_7.0e+00.hdf5
# model_weights_end_1834_8.4e-01.hdf5  model_weights_end_676_3.4e+00.hdf5
# model_weights_end_1846_1.7e+00.hdf5  model_weights_end_692_1.7e+00.hdf5
# model_weights_end_1862_3.4e+00.hdf5  model_weights_end_697_8.4e-01.hdf5
# model_weights_end_1867_7.0e+00.hdf5  model_weights_end_706_4.1e-01.hdf5
# model_weights_end_1875_7.0e+00.hdf5  model_weights_end_714_2.0e-01.hdf5
# model_weights_end_1883_5.0e+00.hdf5  model_weights_end_736_1.0e-01.hdf5
# model_weights_end_1888_3.5e+00.hdf5  model_weights_end_741_4.9e-02.hdf5
# model_weights_end_1900_2.5e+00.hdf5  model_weights_end_842_2.4e-02.hdf5
# model_weights_end_1914_1.8e+00.hdf5  model_weights_end_986_1.2e-02.hdf5
# model_weights_end_1930_1.2e+00.hdf5  vae_args.dat

# %%
generate_sample_plots("model_weights_end_1788_4.9e-02.hdf5", 
                      validation_index=interesting_val_index,
                      base_save_dir="/global/home/users/yifengh3/B_result/annealing_1/jets")
# Out:
# saving to /global/home/users/yifengh3/B_result/annealing_1/jets/jet_sample_1788_0.049

# %%
generate_sample_plots("model_weights_end_2247_1.4e-02.hdf5", validation_index=interesting_val_index,
                      base_save_dir="/global/home/users/yifengh3/B_result/annealing_1/jets")
# Out:
# saving to /global/home/users/yifengh3/B_result/annealing_1/jets/jet_sample_2247_0.014

# %%
generate_sample_plots("model_weights_end_2502_8.6e-02.hdf5", validation_index=interesting_val_index,
                      base_save_dir="/global/home/users/yifengh3/B_result/annealing_1/jets")
# Out:
# saving to /global/home/users/yifengh3/B_result/annealing_1/jets/jet_sample_2502_0.086

# %%
generate_sample_plots("model_weights_end_3560_5.7e-02.hdf5", validation_index=interesting_val_index,
                      base_save_dir="/global/home/users/yifengh3/B_result/annealing_1/jets")
# Out:
# saving to /global/home/users/yifengh3/B_result/annealing_1/jets/jet_sample_3560_0.057

# %%
generate_sample_plots("model_weights_end_3643_3.9e-02.hdf5", validation_index=interesting_val_index,
                      base_save_dir="/global/home/users/yifengh3/B_result/annealing_1/jets")
# Out:
# saving to /global/home/users/yifengh3/B_result/annealing_1/jets/jet_sample_3643_0.039
